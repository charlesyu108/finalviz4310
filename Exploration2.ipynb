# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup

# %%
with open("profiles.csv") as f:
    df = pd.read_csv(f)

# %%
df.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %%
sns.countplot(df.age)

# %%
sns.distplot(df.age)
# Out:
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(y=df.body_type)

# %%
sns.countplot(df.sex)

# %%
sns.countplot(df.height)

# %%
sns.countplot(y=df.ethnicity)

# %%
df.ethnicity.value_counts().head()
# Out:
# white               32831
# asian                6134
# hispanic / latin     2823
# black                2008
# other                1706
# Name: ethnicity, dtype: int64

# %%
df.ethnicity.value_counts().tail()
# Out:
# middle eastern, black, native american, white, other                        1
# black, native american, indian, white                                       1
# indian, pacific islander, hispanic / latin, white                           1
# asian, native american, pacific islander, hispanic / latin, white, other    1
# asian, black, native american, pacific islander, white, other               1
# Name: ethnicity, dtype: int64

# %%
sns.countplot(y=df.diet)

# %%
sns.countplot(y=df.drinks)

# %%
sns.countplot(y=df.education)

# %%
sns.countplot(y=df.income)

# %%
sns.countplot(y=df.job)

# %%
sns.countplot(y=df.location)

# %%
df.location.value_counts().head()
# Out:
# san francisco, california    31064
# oakland, california           7214
# berkeley, california          4212
# san mateo, california         1331
# palo alto, california         1064
# Name: location, dtype: int64

# %%
df.location.value_counts().tail()
# Out:
# utica, michigan                 1
# las vegas, nevada               1
# brea, california                1
# fort lauderdale, florida        1
# south lake tahoe, california    1
# Name: location, dtype: int64

# %%
sns.countplot(y=df.offspring)

# %%
sns.countplot(y=df.orientation)

# %%
sns.countplot(y=df.pets)

# %%
sns.countplot(y=df.religion)

# %%
sns.countplot(y=df.sign)

# %%
for i in range(10):
    df["essay{}".format(i)] = df["essay{}".format(i)].apply(lambda x: str(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def preprocessed(s):
    return BeautifulSoup(s).get_text()

# %%
# Essay0
v0 = TfidfVectorizer(stop_words="english", preprocessor = preprocessed, min_df=10, max_df = 0.95, max_features =200, ngram_range=(1,2))
v0.fit(df[df.location == "san francisco, california"]["essay1"].values.astype('U'))
v0.get_feature_names()
# Out:
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html.parser")
#
#   markup_type=markup_type))
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=zcf46yhizso" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.youtube.com/watch?nr=1&amp;feature=endscreen&amp;v=amehf9iw55m" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=ilwsp0m9g2u" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.sexanddesign.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://ilikeyoualittle.tumblr.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=zvlq3ev0ht4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:219: UserWarning: "b'/'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://tinyurl.com/6nmy79z" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.cleantechlawpartners.com/clp/logan_hollers.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/garygao/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/bs4/__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=yavnowc5ud0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ['actually',
#  'ago',
#  'amazing',
#  'area',
#  'art',
#  'awesome',
#  'balance',
#  'bay',
#  'bay area',
#  'best',
#  'better',
#  'big',
#  'bike',
#  'bit',
#  'building',
#  'business',
#  'busy',
#  'care',
#  'career',
#  'change',
#  'city',
#  'college',
#  'come',
#  'community',
#  'company',
#  'cooking',
#  'cool',
#  'couple',
#  'creative',
#  'currently',
#  'currently working',
#  'dance',
#  'dancing',
#  'day',
#  'days',
#  'degree',
#  'design',
#  'designer',
#  'different',
#  'doing',
#  'don',
#  'dream',
#  'eating',
#  'education',
#  'engineer',
#  'enjoy',
#  'enjoying',
#  'experience',
#  'explore',
#  'exploring',
#  'family',
#  'far',
#  'feel',
#  'figure',
#  'finding',
#  'firm',
#  'food',
#  'francisco',
#  'free',
#  'free time',
#  'friends',
#  'fun',
#  'future',
#  'games',
#  'getting',
#  'going',
#  'good',
#  'got',
#  'grad',
#  'grad school',
#  'great',
#  'hanging',
#  'happy',
#  'hard',
#  'having',
#  'health',
#  'help',
#  'high',
#  'hiking',
#  'home',
#  'hope',
#  'im',
#  'important',
#  'industry',
#  'interesting',
#  'job',
#  'just',
#  'kids',
#  'know',
#  'law',
#  'learn',
#  'learning',
#  'life',
#  'like',
#  'little',
#  'live',
#  'living',
#  'll',
#  'long',
#  'looking',
#  'lot',
#  'lots',
#  'love',
#  'loving',
#  'make',
#  'making',
#  'manager',
#  'marketing',
#  'maybe',
#  'meet',
#  'moment',
#  'money',
#  'months',
#  'moved',
#  'music',
#  'nan',
#  'need',
#  'new',
#  'night',
#  'non',
#  'non profit',
#  'old',
#  'open',
#  'outside',
#  'passion',
#  'past',
#  'people',
#  'person',
#  'place',
#  'places',
#  'plan',
#  'planning',
#  'play',
#  'playing',
#  'possible',
#  'pretty',
#  'profit',
#  'projects',
#  'read',
#  'reading',
#  'real',
#  'really',
#  'recently',
#  'right',
#  'run',
#  'running',
#  'san',
#  'san francisco',
#  'say',
#  'school',
#  'science',
#  'sf',
#  'small',
#  'social',
#  'software',
#  'spend',
#  'spending',
#  'spending time',
#  'spent',
#  'start',
#  'started',
#  'starting',
#  'startup',
#  'student',
#  'studying',
#  'stuff',
#  'summer',
#  'sure',
#  'taking',
#  'teach',
#  'teaching',
#  'tech',
#  'thing',
#  'things',
#  'think',
#  'thinking',
#  'time',
#  'times',
#  'travel',
#  'traveling',
#  'try',
#  'trying',
#  'usually',
#  've',
#  'video',
#  'want',
#  'watching',
#  'way',
#  'week',
#  'weekends',
#  'wine',
#  'work',
#  'worked',
#  'working',
#  'world',
#  'write',
#  'writing',
#  'year',
#  'years',
#  'yoga']

# %%
v0 = TfidfVectorizer(stop_words="english", min_df=10, max_df = 0.95, max_features =200, ngram_range=(1,2))
v0.fit(df[df.location == "san francisco, california"]["essay0"])
v0.get_feature_names()
# Out:
# ['active',
#  'actually',
#  'adventure',
#  'adventures',
#  'ago',
#  'amazing',
#  'amp',
#  'area',
#  'art',
#  'awesome',
#  'bay',
#  'bay area',
#  'beach',
#  'believe',
#  'best',
#  'better',
#  'big',
#  'bike',
#  'bit',
#  'born',
#  'br',
#  'br br',
#  'br like',
#  'br love',
#  'california',
#  'care',
#  'city',
#  'class',
#  'class ilink',
#  'coast',
#  'coffee',
#  'college',
#  'come',
#  'company',
#  'conversation',
#  'cook',
#  'cooking',
#  'creative',
#  'currently',
#  'dance',
#  'dancing',
#  'day',
#  'days',
#  'different',
#  'doing',
#  'don',
#  'east',
#  'easy',
#  'easy going',
#  'eat',
#  'enjoy',
#  'especially',
#  'explore',
#  'exploring',
#  'family',
#  'far',
#  'favorite',
#  'feel',
#  'food',
#  'francisco',
#  'free',
#  'friend',
#  'friends',
#  'fun',
#  'funny',
#  'games',
#  'getting',
#  'girl',
#  'going',
#  'good',
#  'got',
#  'great',
#  'grew',
#  'guy',
#  'happy',
#  'hard',
#  'having',
#  'heart',
#  'hiking',
#  'home',
#  'honest',
#  'href',
#  'href interests',
#  'humor',
#  'ilink',
#  'ilink href',
#  'im',
#  'important',
#  'interested',
#  'interesting',
#  'interests',
#  'job',
#  'just',
#  'kind',
#  'know',
#  'laugh',
#  'learn',
#  'learning',
#  'let',
#  'life',
#  'like',
#  'little',
#  'live',
#  'lived',
#  'living',
#  'll',
#  'long',
#  'look',
#  'looking',
#  'lot',
#  'love',
#  'loving',
#  'make',
#  'makes',
#  'making',
#  'man',
#  'maybe',
#  'meet',
#  'meeting',
#  'mind',
#  'minded',
#  'moved',
#  'movies',
#  'music',
#  'nan',
#  'nature',
#  'need',
#  'new',
#  'new people',
#  'new things',
#  'nice',
#  'night',
#  'old',
#  'open',
#  'originally',
#  'outdoors',
#  'outside',
#  'passionate',
#  'people',
#  'person',
#  'place',
#  'places',
#  'play',
#  'playing',
#  'pretty',
#  'probably',
#  'profile',
#  'quite',
#  'raised',
#  'read',
#  'reading',
#  'really',
#  'recently',
#  'relationship',
#  'right',
#  'running',
#  'san',
#  'san francisco',
#  'say',
#  'school',
#  'self',
#  'sense',
#  'sense humor',
#  'seriously',
#  'sf',
#  'share',
#  'smart',
#  'social',
#  'spend',
#  'spent',
#  'sports',
#  'strong',
#  'stuff',
#  'taking',
#  'talk',
#  'tell',
#  'tend',
#  'thing',
#  'things',
#  'think',
#  'time',
#  'times',
#  'travel',
#  'traveling',
#  'try',
#  'trying',
#  'usually',
#  've',
#  'want',
#  'watch',
#  'watching',
#  'way',
#  'went',
#  'wine',
#  'work',
#  'working',
#  'world',
#  'write',
#  'year',
#  'years']

# %%
with open("profiles_fixed3.csv") as f:
    df2 = pd.read_csv(f)

# %%
for i in range(10):
    df2["essay{}".format(i)] = df2["essay{}".format(i)].apply(lambda x: str(x))

v2 = TfidfVectorizer(stop_words="english", min_df=10, max_df = 0.95, max_features =200, ngram_range=(1,2))
v2.fit(df2[df2.location == "san francisco, california"]["essay0"])
v2.get_feature_names()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-82e194fcca47> in <module>()
#       3
#       4 v2 = TfidfVectorizer(stop_words="english", min_df=10, max_df = 0.95, max_features =200, ngram_range=(1,2))
# ----> 5 v2.fit(df2[df2.location == "san francisco, california"]["essay0"])
#       6 v2.get_feature_names()
#
# ~/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#    1359         self : TfidfVectorizer
#    1360         """
# -> 1361         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1362         self._tfidf.fit(X)
#    1363         return self
#
# ~/Desktop/finalviz4310/final_venv/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     884             if max_doc_count < min_doc_count:
#     885                 raise ValueError(
# --> 886                     "max_df corresponds to < documents than min_df")
#     887             X, self.stop_words_ = self._limit_features(X, vocabulary,
#     888                                                        max_doc_count,
#
# ValueError: max_df corresponds to < documents than min_df

# %%
df['last_online'] = pd.to_datetime(df['last_online'])

# %%
df['last_online']
# Out:
# 0       2012-06-30 02:00:00
# 1       2012-07-01 14:00:00
# 2       2012-06-27 19:00:00
# 3       2012-06-29 12:00:00
# 4       2012-06-28 23:00:00
# 5       2012-06-30 13:00:00
# 6       2012-06-27 17:00:00
# 7       2012-06-30 18:00:00
# 8       2012-07-01 14:00:00
# 9       2012-06-29 05:00:00
# 10      2012-06-07 01:00:00
# 11      2012-05-22 22:00:00
# 12      2012-05-30 01:00:00
# 13      2012-06-13 22:00:00
# 14      2012-07-01 15:00:00
# 15      2012-06-30 07:00:00
# 16      2012-06-30 00:00:00
# 17      2012-06-30 14:00:00
# 18      2012-06-29 08:00:00
# 19      2012-06-29 14:00:00
# 20      2012-06-28 12:00:00
# 21      2012-06-18 06:00:00
# 22      2012-06-29 13:00:00
# 23      2012-05-18 19:00:00
# 24      2012-07-01 05:00:00
# 25      2012-06-27 04:00:00
# 26      2012-06-11 14:00:00
# 27      2012-06-26 05:00:00
# 28      2012-06-19 23:00:00
# 29      2012-06-29 08:00:00
#                 ...
# 59916   2012-06-29 04:00:00
# 59917   2012-01-26 00:00:00
# 59918   2011-07-11 15:00:00
# 59919   2011-12-24 00:00:00
# 59920   2012-06-26 23:00:00
# 59921   2012-07-02 21:00:00
# 59922   2012-03-24 00:00:00
# 59923   2012-07-02 10:00:00
# 59924   2012-06-28 01:00:00
# 59925   2012-03-20 09:00:00
# 59926   2012-06-16 13:00:00
# 59927   2012-07-02 09:00:00
# 59928   2012-01-26 00:00:00
# 59929   2012-06-06 04:00:00
# 59930   2011-10-19 16:00:00
# 59931   2012-04-18 10:00:00
# 59932   2011-12-21 17:00:00
# 59933   2012-07-01 11:00:00
# 59934   2012-07-02 08:00:00
# 59935   2012-06-03 00:00:00
# 59936   2012-07-01 11:00:00
# 59937   2012-02-19 16:00:00
# 59938   2012-06-16 19:00:00
# 59939   2012-07-01 14:00:00
# 59940   2012-07-02 16:00:00
# 59941   2012-06-14 20:00:00
# 59942   2012-06-29 12:00:00
# 59943   2012-06-29 12:00:00
# 59944   2012-06-23 14:00:00
# 59945   2012-06-30 18:00:00
# Name: last_online, Length: 59946, dtype: datetime64[ns]

# %%
mask = (df['last_online'] >= '2012-05-01') & (df['last_online'] <= '2013-05-01')

# %%
# df2 = df.set_index(['last_online'])
# # print(df2)
# print(df2['2012-05-01':'2013-05-01'])

# %%
meep = df.loc[(df['location'] == "san francisco, california") & mask]

# %%
meep.to_csv('meep.csv')
